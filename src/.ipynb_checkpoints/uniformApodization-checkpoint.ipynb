# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Input, BatchNormalization, LeakyReLU
from tensorflow.keras import Sequential, Model
from tensorflow.keras.models import load_model
from sklearn.model_selection import train_test_split
from  tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import random
# %matplotlib inline

# %%
class Item:
    def __init__(self, minv, maxv):
        self.min = minv
        self.max = maxv

lRange = Item(500, 3000)  # increasing l would introduce oscillations
dnRange = Item(9e-4, 1e-3)
n0Range = Item(1.47, 1.49)
netaRange = Item(0.75, 0.95)
pitchRange = Item(0.510135135, 0.515891892)
xRange = Item(1.5, 1.54)
xMaxRange = Item(1.51, 1.53)
nSamples = 300
nVariables = 5

# %%
dataPath = 'data_300d_300000m.npz'
with np.load(dataPath) as data:
    xTrain = data["xTrain"]
    xTest = data["xTest"]
    yTrain = data["yTrain"]
    yTest = data["yTest"]

print("shape of xTrain :", xTrain.shape)
print("shape of yTrain :", yTrain.shape)
print("shape of xTest :", xTest.shape)
print("shape of yTest :", yTest.shape)
# Out:
# shape of xTrain : (240000, 5)
# shape of yTrain : (240000, 300)
# shape of xTest : (60000, 5)
# shape of yTest : (60000, 300)

# %%
# build forward model
fwdInputShape = xTrain.shape[1:]
fwdOutputUnits = yTrain.shape[1]
bwdInputShape = yTrain.shape[1:]
bwdOutputUnits = xTrain.shape[1]

inputs = Input(shape=fwdInputShape, name='fwd_input_layer')
x = Dense(256, activation='relu', name='layer1')(inputs)
x = BatchNormalization()(x)
x = Dense(256, activation='relu', name='layer2')(x)
x = BatchNormalization()(x)
x = Dense(256, activation='relu', name='layer3')(x)
x = BatchNormalization()(x)
x = Dense(256, activation='relu', name='layer4')(x)
x = BatchNormalization()(x)
outputs = Dense(fwdOutputUnits, name='fwd_output_layer', activation='sigmoid')(x)

fwd = Model(inputs=inputs, outputs=outputs)
fwd.compile(loss='mse', optimizer='adam', metrics=['accuracy'])

# train forward model

# %%
class TandemModel:
    """
    l     : length of the grating
    dn    : shift in refractive index
    neta  : pecentage of power in the core
    pitch : pitch of the grating
    x     : lambda range
    """
    class Item:
        def __init__(self, minv, maxv):
            self.min = minv
            self.max = maxv

    lRange = Item(500, 3000)  # increasing l would introduce oscillations
    dnRange = Item(9e-4, 1e-3)
    n0Range = Item(1.47, 1.49)
    netaRange = Item(0.75, 0.95)
    pitchRange = Item(0.510135135, 0.515891892)
    xRange = Item(1.5, 1.54)
    xMaxRange = Item(1.51, 1.53)
    nSamples = 300
    nVariables = 5
    
    
    def __init__(self, dataPath):
        self.path = dataPath
        self.xTrain = None
        self.yTrain = None
        self.xTest = None
        self.yTest = None
        
        # load data
        with np.load(self.path) as data:
            self.xTrain, self.xTest, self.yTrain, self.yTest = data['xTrain'], data['xTest'], data['yTrain'], data['yTest']
            
        self.fwdInputShape = self.xTrain.shape[1:]
        self.fwdOutputUnits = self.yTrain.shape[1]

        self.bwdInputShape = self.yTrain.shape[1:]
        self.bwdOutputUnits = self.xTrain.shape[1]
        
        self.fwd = None
        self.bwd = None
        self.tandem = None
        
        # A-law parameter
        self.A = 87.7
        # mu-law parameter
        self.mu = 255

    def apply_non_linear(self, law='A'):
        self.y_train = self.non_linear_filter(self.y_train, law)
        self.y_test = self.non_linear_filter(self.y_test, law)
    
    def non_linear_filter(self, x, law='A'):
        if law == 'A':
            return (1+np.log(self.A*x))/(1+np.log(self.A))
        else:
            return np.log(1+self.mu*x)/np.log(1+self.mu)
        
    def inverse(self, x, law='A'):
        if law == 'A':
            return np.exp(x*(1+np.log(self.A))-1)/self.A
        else:
            return ((1+self.mu)**x - 1)/self.mu
    
    
    def build_fwd_model(self):
        """
        predicts target response based on design parameters
        """
        self.fwd = Sequential(name='fwd_model')
        
        inputs = Input(shape=self.fwdInputShape, name='fwd_input_layer')
        
        x = Dense(256, activation='relu', name='layer1')(inputs)
        x = BatchNormalization()(x)
        x = Dense(256, activation='relu', name='layer2')(x)
        x = BatchNormalization()(x)
        x = Dense(256, activation='relu', name='layer3')(x)
        x = BatchNormalization()(x)
        x = Dense(256, activation='relu', name='layer4')(x)
        x = BatchNormalization()(x)
        
        outputs = Dense(self.fwdOutputUnits, name='fwd_output_layer', activation='sigmoid')(x)

        self.fwd = Model(inputs=inputs, outputs=outputs)

    
    def load_fwd_saved_model(self, path):
        self.fwd = load_model(path)
        
    
    def build_bwd_model(self):
        """
        predicts design parameters based on target response
        """
        inputs = Input(shape=self.bwdInputShape, name='bwd_input_layer')
        
        x = Dense(64, activation='relu', name='bwd_hidden_layer1')(inputs)
        x = BatchNormalization()(x)
        x = Dense(64, activation='relu', name='bwd_hidden_layer2')(x)
        x = BatchNormalization()(x)
        x = Dense(64, activation='relu', name='bwd_hidden_layer3')(x)
        x = BatchNormalization()(x)
        x = Dense(32, activation='relu', name='bwd_hidden_layer4')(x)
        x = BatchNormalization()(x)
        x = Dense(self.bwdOutputUnits, name='bwd_output_layer', activation='sigmoid')(x)
        
        self.bwd = Model(inputs, x)
    

    def build_tandem_model(self):
        x = self.bwd.output
        
        for layer in self.fwd.layers[1:]:
            layer.trainable = False
            x = layer(x)
            
        self.tandem = Model(inputs=self.bwd.input, outputs=x)
        
    
    def load_bwd_saved_model(self, path):
        self.bwd = load_model(path)
    
    
    def summary(self, model='fwd'):
        if(model == 'fwd'):
            return self.fwd.summary()
        return self.bwd.summary()
    
    
    def fit_fwd(self, batchSize=64, epochs=5, validationSplit=0.2):
        return self.fwd.fit(self.xTrain, self.yTrain, batch_size=batchSize, epochs=epochs, validation_split=0.2, shuffle=True)
        
    
    def save_model(self, path, model='fwd'):
        if model == 'fwd':
            self.fwd.save(path)
        else:
            self.bwd.save(path)
    
    def plot(self, history):
        plt.plot(history.epoch, history.history['accuracy'])
        plt.plot(history.epoch, history.history['loss'])
        plt.xlabel('epochs')
        plt.legend(['accuracy', 'loss'], loc='upper left')

# %%
tandem = TandemModel(dataPath)

# %%
print((tandem.fwdInputShape, tandem.fwdOutputUnits), (tandem.bwdInputShape, tandem.bwdOutputUnits))
# Out:
# ((5,), 300) ((300,), 5)

# %%
# train fwd model
filtered = False
tandem.build_fwd_model()
# tandem.apply_non_linear('A')
tandem.summary()
tandem.fwd.compile(loss='mse', optimizer='adam', metrics=['accuracy'])
tandem.fit_fwd(batchSize=256, epochs=30, validationSplit=0.002)
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# fwd_input_layer (InputLayer) [(None, 5)]               0
# _________________________________________________________________
# layer1 (Dense)               (None, 256)               1536
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256)               1024
# _________________________________________________________________
# layer2 (Dense)               (None, 256)               65792
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 256)               1024
# _________________________________________________________________
# layer3 (Dense)               (None, 256)               65792
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 256)               1024
# _________________________________________________________________
# layer4 (Dense)               (None, 256)               65792
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 256)               1024
# _________________________________________________________________
# fwd_output_layer (Dense)     (None, 300)               77100
# =================================================================
# Total params: 280,108
# Trainable params: 278,060
# Non-trainable params: 2,048
# _________________________________________________________________
# Epoch 1/30
# 750/750 [==============================] - 9s 10ms/step - loss: 0.0784 - accuracy: 0.0403 - val_loss: 0.0086 - val_accuracy: 0.1414
# Epoch 2/30
# 750/750 [==============================] - 7s 9ms/step - loss: 0.0097 - accuracy: 0.0880 - val_loss: 0.0069 - val_accuracy: 0.1654
# Epoch 3/30
# 750/750 [==============================] - 7s 10ms/step - loss: 0.0088 - accuracy: 0.0935 - val_loss: 0.0052 - val_accuracy: 0.2009
# Epoch 4/30
# 750/750 [==============================] - 8s 10ms/step - loss: 0.0077 - accuracy: 0.1125 - val_loss: 0.0080 - val_accuracy: 0.0607
# Epoch 5/30
# 750/750 [==============================] - 7s 10ms/step - loss: 0.0070 - accuracy: 0.1257 - val_loss: 0.0039 - val_accuracy: 0.2488
# Epoch 6/30
# 750/750 [==============================] - 7s 10ms/step - loss: 0.0064 - accuracy: 0.1355 - val_loss: 0.0056 - val_accuracy: 0.1388
# Epoch 7/30
# 750/750 [==============================] - 7s 10ms/step - loss: 0.0059 - accuracy: 0.1479 - val_loss: 0.0052 - val_accuracy: 0.2580
# Epoch 8/30
# 750/750 [==============================] - 8s 10ms/step - loss: 0.0057 - accuracy: 0.1557 - val_loss: 0.0053 - val_accuracy: 0.1904
# Epoch 9/30
# 750/750 [==============================] - 8s 10ms/step - loss: 0.0054 - accuracy: 0.1575 - val_loss: 0.0044 - val_accuracy: 0.1584
# Epoch 10/30
# 750/750 [==============================] - 8s 10ms/step - loss: 0.0048 - accuracy: 0.1820 - val_loss: 0.0030 - val_accuracy: 0.2634
# Epoch 11/30
# 750/750 [==============================] - 8s 10ms/step - loss: 0.0043 - accuracy: 0.2027 - val_loss: 0.0040 - val_accuracy: 0.1370
# Epoch 12/30
# 750/750 [==============================] - 8s 10ms/step - loss: 0.0035 - accuracy: 0.2390 - val_loss: 0.0036 - val_accuracy: 0.3010
# Epoch 13/30
# 750/750 [==============================] - 8s 11ms/step - loss: 0.0032 - accuracy: 0.2593 - val_loss: 0.0025 - val_accuracy: 0.2979
# Epoch 14/30
# 750/750 [==============================] - 8s 10ms/step - loss: 0.0030 - accuracy: 0.2724 - val_loss: 0.0042 - val_accuracy: 0.1210
# Epoch 15/30
# 750/750 [==============================] - 8s 10ms/step - loss: 0.0028 - accuracy: 0.2851 - val_loss: 0.0022 - val_accuracy: 0.3004
# Epoch 16/30
# 750/750 [==============================] - 8s 10ms/step - loss: 0.0024 - accuracy: 0.3189 - val_loss: 0.0022 - val_accuracy: 0.3109
# Epoch 17/30
# 750/750 [==============================] - 8s 11ms/step - loss: 0.0023 - accuracy: 0.3183 - val_loss: 0.0022 - val_accuracy: 0.3539
# Epoch 18/30
# 750/750 [==============================] - 8s 10ms/step - loss: 0.0021 - accuracy: 0.3421 - val_loss: 0.0025 - val_accuracy: 0.3306
# Epoch 19/30
# 750/750 [==============================] - 8s 11ms/step - loss: 0.0020 - accuracy: 0.3490 - val_loss: 0.0020 - val_accuracy: 0.3935
# Epoch 20/30
# 750/750 [==============================] - 8s 10ms/step - loss: 0.0019 - accuracy: 0.3664 - val_loss: 0.0021 - val_accuracy: 0.2834
# Epoch 21/30
# 750/750 [==============================] - 8s 10ms/step - loss: 0.0018 - accuracy: 0.3867 - val_loss: 0.0028 - val_accuracy: 0.2949
# Epoch 22/30
# 750/750 [==============================] - 8s 10ms/step - loss: 0.0018 - accuracy: 0.3853 - val_loss: 0.0014 - val_accuracy: 0.4342
# Epoch 23/30
# 750/750 [==============================] - 8s 10ms/step - loss: 0.0016 - accuracy: 0.4027 - val_loss: 0.0014 - val_accuracy: 0.4665
# Epoch 24/30
# 750/750 [==============================] - 8s 10ms/step - loss: 0.0015 - accuracy: 0.4162 - val_loss: 0.0020 - val_accuracy: 0.3201
# Epoch 25/30
# 750/750 [==============================] - 8s 10ms/step - loss: 0.0016 - accuracy: 0.4112 - val_loss: 0.0011 - val_accuracy: 0.4971
# Epoch 26/30
# 750/750 [==============================] - 8s 10ms/step - loss: 0.0014 - accuracy: 0.4382 - val_loss: 0.0015 - val_accuracy: 0.3830
# Epoch 27/30
# 750/750 [==============================] - 8s 11ms/step - loss: 0.0014 - accuracy: 0.4402 - val_loss: 0.0021 - val_accuracy: 0.2790
# Epoch 28/30
# 750/750 [==============================] - 7s 10ms/step - loss: 0.0015 - accuracy: 0.4218 - val_loss: 0.0013 - val_accuracy: 0.4647
# Epoch 29/30
# 750/750 [==============================] - 8s 10ms/step - loss: 0.0013 - accuracy: 0.4494 - val_loss: 0.0010 - val_accuracy: 0.5291
# Epoch 30/30
# 750/750 [==============================] - 8s 10ms/step - loss: 0.0013 - accuracy: 0.4477 - val_loss: 0.0012 - val_accuracy: 0.4831

# %%
# test fwd model
predictions = tandem.fwd.predict(tandem.xTrain)

d = (tandem.xRange.max - tandem.xRange.min)/tandem.nSamples
x = []
start = tandem.xRange.min

for _ in range(tandem.nSamples):
    x.append(start)
    start = start + d

x = np.array(x)
# plot the predictions
random_samples = [random.randint(0, len(predictions)) for _ in range(50)]
for i in random_samples:
    fig, ax = plt.subplots()
    
    if filtered:
        ax.plot(tandem.inverse(tandem.yTrain[i]))
        ax.plot(tandem.inverse(predictions[i]))
    else:
        ax.plot(x, tandem.yTrain[i])
        ax.plot(x, predictions[i])
    
    ax.legend(['actual', 'prediction'], loc='upper left')
# Out:
# /home/ninja/studies/my-sem-8/BTP/src/env/lib/python3.7/site-packages/ipykernel_launcher.py:16: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   app.launch_new_instance()

# %%
# save the fwd model
tandem.fwd.save('fwd_256x256x256x256_50epochs_1e-4_adam_200000')

# %%
del tandem

tandem = TandemModel(TRAIN_DATA_PATH)
tandem.load_fwd_saved_model('fwd_256x256x256x256_50epochs_1e-4_adam_200000')
tandem.build_bwd_model()
tandem.build_tandem_model()
tandem.bwd.summary()
tandem.fwd.summary()
# tandem.tandem.summary()
tandem.tandem.compile(loss='mse', optimizer='adam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bwd_input_layer (InputLayer) [(None, 300)]             0
# _________________________________________________________________
# bwd_hidden_layer1 (Dense)    (None, 64)                19264
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 64)                256
# _________________________________________________________________
# bwd_hidden_layer2 (Dense)    (None, 64)                4160
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 64)                256
# _________________________________________________________________
# bwd_hidden_layer3 (Dense)    (None, 64)                4160
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 64)                256
# _________________________________________________________________
# bwd_hidden_layer4 (Dense)    (None, 32)                2080
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 32)                128
# _________________________________________________________________
# bwd_output_layer (Dense)     (None, 5)                 165
# =================================================================
# Total params: 30,725
# Trainable params: 30,277
# Non-trainable params: 448
# _________________________________________________________________
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# fwd_input_layer (InputLayer) [(None, 5)]               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               1536
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 256)               1024
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               65792
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 256)               1024
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               65792
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 256)               1024
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               65792
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 256)               1024
# _________________________________________________________________
# fwd_output_layer (Dense)     (None, 300)               77100
# =================================================================
# Total params: 280,108
# Trainable params: 0
# Non-trainable params: 280,108
# _________________________________________________________________

# %%
history = tandem.tandem.fit(tandem.y_train, tandem.y_train, epochs=20, batch_size=256, validation_split=0.02, shuffle=True)
# Out:
# Train on 156800 samples, validate on 3200 samples
# Epoch 1/20
# 156800/156800 [==============================] - 8s 49us/sample - loss: 6.5632e-04 - acc: 0.1745 - val_loss: 6.6221e-04 - val_acc: 0.2025
# Epoch 2/20
# 156800/156800 [==============================] - 8s 52us/sample - loss: 6.3047e-04 - acc: 0.1784 - val_loss: 6.0150e-04 - val_acc: 0.2075
# Epoch 3/20
# 156800/156800 [==============================] - 8s 53us/sample - loss: 6.1897e-04 - acc: 0.1755 - val_loss: 5.2296e-04 - val_acc: 0.2284
# Epoch 4/20
# 156800/156800 [==============================] - 8s 52us/sample - loss: 5.6579e-04 - acc: 0.1772 - val_loss: 4.0427e-04 - val_acc: 0.2191
# Epoch 5/20
# 156800/156800 [==============================] - 8s 51us/sample - loss: 5.7256e-04 - acc: 0.1767 - val_loss: 3.3605e-04 - val_acc: 0.2131
# Epoch 6/20
# 156800/156800 [==============================] - 8s 49us/sample - loss: 5.3696e-04 - acc: 0.1788 - val_loss: 8.1932e-04 - val_acc: 0.1994
# Epoch 7/20
# 156800/156800 [==============================] - 8s 50us/sample - loss: 5.5984e-04 - acc: 0.1766 - val_loss: 4.5933e-04 - val_acc: 0.2200
# Epoch 8/20
# 156800/156800 [==============================] - 8s 50us/sample - loss: 5.2369e-04 - acc: 0.1781 - val_loss: 2.9528e-04 - val_acc: 0.2244
# Epoch 9/20
# 156800/156800 [==============================] - 8s 50us/sample - loss: 5.1874e-04 - acc: 0.1774 - val_loss: 3.9874e-04 - val_acc: 0.2262
# Epoch 10/20
# 156800/156800 [==============================] - 8s 51us/sample - loss: 4.9028e-04 - acc: 0.1798 - val_loss: 6.4415e-04 - val_acc: 0.2047
# Epoch 11/20
# 156800/156800 [==============================] - 8s 49us/sample - loss: 4.7540e-04 - acc: 0.1804 - val_loss: 4.1370e-04 - val_acc: 0.2159
# Epoch 12/20
# 156800/156800 [==============================] - 8s 50us/sample - loss: 4.9473e-04 - acc: 0.1793 - val_loss: 4.5591e-04 - val_acc: 0.2087
# Epoch 13/20
# 156800/156800 [==============================] - 8s 51us/sample - loss: 4.6656e-04 - acc: 0.1807 - val_loss: 3.4023e-04 - val_acc: 0.2341
# Epoch 14/20
# 156800/156800 [==============================] - 8s 51us/sample - loss: 4.6596e-04 - acc: 0.1785 - val_loss: 3.1982e-04 - val_acc: 0.2131
# Epoch 15/20
# 156800/156800 [==============================] - 8s 50us/sample - loss: 5.0996e-04 - acc: 0.1795 - val_loss: 3.0343e-04 - val_acc: 0.2131
# Epoch 16/20
# 156800/156800 [==============================] - 8s 54us/sample - loss: 4.8577e-04 - acc: 0.1774 - val_loss: 3.4052e-04 - val_acc: 0.2169
# Epoch 17/20
# 156800/156800 [==============================] - 8s 53us/sample - loss: 4.2218e-04 - acc: 0.1799 - val_loss: 2.7610e-04 - val_acc: 0.2150
# Epoch 18/20
# 156800/156800 [==============================] - 9s 55us/sample - loss: 4.5120e-04 - acc: 0.1782 - val_loss: 3.1764e-04 - val_acc: 0.2144
# Epoch 19/20
# 156800/156800 [==============================] - 8s 50us/sample - loss: 4.3647e-04 - acc: 0.1795 - val_loss: 4.5143e-04 - val_acc: 0.2116
# Epoch 20/20
# 156800/156800 [==============================] - 8s 52us/sample - loss: 4.1818e-04 - acc: 0.1797 - val_loss: 3.0703e-04 - val_acc: 0.2197

# %%
tandem.tandem

# %%
tandem.tandem.evaluate(tandem.yTest, tandem.yTest)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-b2dbef921305> in <module>
# ----> 1 tandem.tandem.evaluate(tandem.yTest, tandem.yTest)
#
# AttributeError: 'NoneType' object has no attribute 'evaluate'

# %%
# test on examples
predictions = tandem.tandem.predict(tandem.y_test)
x = 
random_samples = [random.randint(0, len(predictions)) for _ in range(50)]
for i in random_samples:
    fig, ax = plt.subplots()
    
    ax.plot(tandem.y_test[i])
    ax.plot(predictions[i])
    
    ax.legend(['actual', 'prediction'], loc='upper left')
    ax.title('')
# Out:
# /home/ninja/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """

# %%
# save bwd model
tandem.bwd.save('bwd_64x64x64x32_50epochs_4e-4_adam_200000')

# %%
# save tandem model
tandem.tandem.save('tandem_fwd_256x256x256x256_50epochs_1e-4_adam_bwd_64x64x64x32_50epochs_4e-4_adam_200000')

# %%
# train model without tandem network
tandem.build_bwd_model()
bwd = tandem.bwd
bwd.summary()
# Out:
# WARNING:tensorflow:From /home/ninja/anaconda3/envs/DS1_env/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bwd_input_layer (InputLayer) [(None, 300)]             0
# _________________________________________________________________
# bwd_hidden_layer1 (Dense)    (None, 64)                19264
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64)                256
# _________________________________________________________________
# bwd_hidden_layer2 (Dense)    (None, 64)                4160
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# bwd_hidden_layer3 (Dense)    (None, 64)                4160
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64)                256
# _________________________________________________________________
# bwd_hidden_layer4 (Dense)    (None, 32)                2080
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32)                128
# _________________________________________________________________
# bwd_output_layer (Dense)     (None, 5)                 165
# =================================================================
# Total params: 30,725
# Trainable params: 30,277
# Non-trainable params: 448
# _________________________________________________________________

# %%
bwd.compile(loss='mse', optimizer='adam', metrics=['accuracy'])
bwd.fit(tandem.y_train[:100000], tandem.x_train[:100000], epochs=1, batch_size=256, shuffle=True)
# Out:
# 100000/100000 [==============================] - 3s 26us/sample - loss: 0.0404 - acc: 0.4447

# %%
bwd.save('bwd_without_tandem_64x64x64x32_10epoch_0.0404')
